# %%
import numpy as np
import matplotlib.pyplot as plt
import mkl

mkl.set_num_threads(4)
np.random.seed(1234)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]

# %% [markdown]
# ### Handy utility functions

# %%
def append_ones(matrix, axis=1):
    return np.concatenate((matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=axis)

def zeros(*dims):
    return np.zeros(shape=tuple(dims), dtype=np.float32)

def ones(*dims):
    return np.ones(shape=tuple(dims), dtype=np.float32)

def rand(*dims):
    return np.random.rand(*dims).astype(np.float32)

def chunks(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

def tiles(examples):
    rows_count = examples.shape[0]
    cols_count = examples.shape[1]
    tile_height = examples.shape[2]
    tile_width = examples.shape[3]
    
    space_between_tiles = 2
    img_matrix = np.empty(shape=(rows_count * (tile_height + space_between_tiles) - space_between_tiles,  
                                 cols_count * (tile_width + space_between_tiles) - space_between_tiles))
    img_matrix.fill(np.nan)

    for r in range(rows_count):
        for c in range(cols_count):
            x_0 = r * (tile_height + space_between_tiles)
            y_0 = c * (tile_width + space_between_tiles)
            ex_min = np.min(examples[r, c])
            ex_max = np.max(examples[r, c])
            img_matrix[x_0:x_0 + tile_height, y_0:y_0 + tile_width] = (examples[r, c] - ex_min) / (ex_max - ex_min)
    
    plt.matshow(img_matrix, cmap='gray', interpolation='none')
    plt.axis('off')
    plt.show()

# %% [markdown]
# # MNIST dataset

# %%
import mnist
digits = np.reshape(mnist.train_images()[:12*24], newshape=(12, 24, 28, 28))
tiles(digits)

# %% [markdown]
# # Restricted Boltzmann Machine & Contrastive Divergence algorithm

# %%
def sigmoid(matrix):
    return 1.0 / (1.0 + np.exp(-matrix))

class Rbm:
    def __init__(self, visible_size, hidden_size, learning_rate, momentum):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size+1)).astype(np.float32)
        self.W[:, -1] = 0.0
        self.W[-1, :] = 0.0
        self.M = zeros(self.visible_size+1, self.hidden_size+1)

# %%
def reconstuction_error(rbm, minibatch):
    observations_count = minibatch.shape[0]
    visible = zeros(observations_count, rbm.visible_size)
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))

    hidden[:, :-1] = sigmoid(minibatch @ rbm.W[:, :-1]) > rand(hidden.shape[0], hidden.shape[1] - 1)
    visible = sigmoid(hidden @ rbm.W[:-1, :].T)

    error = np.sum((minibatch[:, :-1] - visible)**2) /observations_count
    return error

# %%
def train_epoch(rbm, dataset, batch_size):
    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(rbm, batch)
        if batch_idx % round(batches_limit / 50) == 0: print("#", end="")

def run_training(rbm, dataset, monitoring_set, batch_size, epochs_count):
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch),  end="\t")
        
        if epoch == 5:
            rbm.momentum = 0.8

        start_time = time.time()
        train_epoch(rbm, dataset, batch_size)
        elapsed = time.time() - start_time
        
        error = reconstuction_error(rbm, monitoring_set)
        print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))

    print("Training finished!")

# %%
def draw_filters(rbm):
    filters = np.reshape(np.transpose(rbm.W)[:-1, :-1], newshape=(8, -1, 28, 28))
    tiles(filters)

# %% [markdown]
# # 1. RBM Training with momentum

# %%
def cdk(rbm, minibatch, k=1):
    observations_count = minibatch.shape[0]

    #activation matrices during positive and negative phases in visible (v) layer,with bias
    positive_visible = minibatch
    negative_visible = append_ones(zeros(observations_count, rbm.visible_size))
    
    #activation matrices during positive and negative phases in hidden (h) layer,with bias
    positive_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    negative_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
    # positive phase
    vW = positive_visible @ rbm.W[:,:-1] #multiply visible v and W
    positive_hidden[:, :-1] = sigmoid(vW) #get hidden from sigmoid
    positive_vh = (positive_visible.T @ positive_hidden) / observations_count
    
    #negative phase
    # gibbs sampling
    # remove last column (hidden layer) or last row (visible layer) from the weight matrix W
    # since those are biases and should always be 1
    positive_h_rand_shape = positive_hidden.shape[0], positive_hidden.shape[1] - 1
    negative_h_rand_shape = negative_hidden.shape[0], negative_hidden.shape[1] - 1
    negative_v_rand_shape = negative_visible.shape[0], negative_visible.shape[1] - 1
    
    #sample hidden layer, get h_0
    negative_hidden[:, :-1] = positive_hidden[:, :-1] > rand(*positive_h_rand_shape)
    
    #sample visible layer, get v_1
    negative_visible[:, :-1] = sigmoid(negative_hidden @ rbm.W[:-1, :].T) > rand(*negative_v_rand_shape)
    
    for i in range(k - 1):
        nvW1 = negative_visible @ rbm.W[:,:-1]
        # sample hidden layer, het h_{k-1}
        negative_hidden[:, :-1] = sigmoid(nvW1 ) > rand(*negative_h_rand_shape)
    
        nhW1 = negative_hidden @ rbm.W[:,:-1]
        #sample visible layer, get v_k
        negative_visible[:, :-1] = sigmoid(nhW1) > rand(*negative_v_rand_shape)
        
    #h_k, to match v_k
    nvW = negative_visible @ rbm.W[:,:-1]
    negative_hidden[:, :-1] = sigmoid(nvW)
    neg_grad = (negative_visible.T @ negative_hidden) / observations_count
    
    # Weight update
    rbm.W = rbm.W + rbm.learning_rate * positive_vh - rbm.learning_rate * neg_grad

# %%
import time

DATASET_SIZE = 20000 # 60000 for whole dataset
DIGIT_SIZE = 28

VISIBLE_LAYER_SIZE = DIGIT_SIZE*DIGIT_SIZE
HIDDEN_LAYER_SIZE = 128

mnist_train = mnist.train_images().astype(np.float32) / 255.0
np.random.shuffle(mnist_train)
dataset = np.reshape(mnist_train[:DATASET_SIZE], newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
dataset = append_ones(dataset)

monitoring_indeces = np.random.choice(DATASET_SIZE, 256, replace=False)
monitoring_set = dataset[monitoring_indeces]

# %%
BATCH_SIZE = 128
EPOCHS_COUNT = 50

LEARNING_RATE = 0.1
MOMENTUM = 0.5

rbm = Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM)
draw_filters(rbm)

run_training(rbm, dataset, monitoring_set, BATCH_SIZE, EPOCHS_COUNT)

draw_filters(rbm)
# Out:
# Epoch 0:	#####################################################	elapsed: 1.46s, reconstruction error: 32.27
# Epoch 1:	#####################################################	elapsed: 2.16s, reconstruction error: 26.07
# Epoch 2:	#####################################################	elapsed: 2.49s, reconstruction error: 22.65
# Epoch 3:	#####################################################	elapsed: 2.15s, reconstruction error: 20.63
# Epoch 4:	#####################################################	elapsed: 2.16s, reconstruction error: 19.20
# Epoch 5:	#####################################################	elapsed: 1.50s, reconstruction error: 18.34
# Epoch 6:	#####################################################	elapsed: 1.40s, reconstruction error: 17.35
# Epoch 7:	#####################################################	elapsed: 1.71s, reconstruction error: 16.89
# Epoch 8:	#####################################################	elapsed: 1.66s, reconstruction error: 16.41
# Epoch 9:	#####################################################	elapsed: 1.11s, reconstruction error: 15.92
# Epoch 10:	#####################################################	elapsed: 1.81s, reconstruction error: 15.50
# Epoch 11:	#####################################################	elapsed: 2.06s, reconstruction error: 15.03
# Epoch 12:	#####################################################	elapsed: 1.72s, reconstruction error: 14.89
# Epoch 13:	#####################################################	elapsed: 1.00s, reconstruction error: 14.43
# Epoch 14:	#####################################################	elapsed: 2.02s, reconstruction error: 14.27
# Epoch 15:	#####################################################	elapsed: 1.48s, reconstruction error: 14.01
# Epoch 16:	#####################################################	elapsed: 1.19s, reconstruction error: 14.01
# Epoch 17:	#####################################################	elapsed: 1.54s, reconstruction error: 13.64
# Epoch 18:	#####################################################	elapsed: 1.93s, reconstruction error: 13.52
# Epoch 19:	#####################################################	elapsed: 2.24s, reconstruction error: 13.30
# Epoch 20:	#####################################################	elapsed: 2.13s, reconstruction error: 13.12
# Epoch 21:	#####################################################	elapsed: 2.09s, reconstruction error: 13.01
# Epoch 22:	#####################################################	elapsed: 2.03s, reconstruction error: 12.77
# Epoch 23:	#####################################################	elapsed: 2.08s, reconstruction error: 12.70
# Epoch 24:	#####################################################	elapsed: 2.11s, reconstruction error: 12.41
# Epoch 25:	#####################################################	elapsed: 2.03s, reconstruction error: 12.68
# Epoch 26:	#####################################################	elapsed: 2.04s, reconstruction error: 12.33
# Epoch 27:	#####################################################	elapsed: 2.01s, reconstruction error: 12.23
# Epoch 28:	#####################################################	elapsed: 2.01s, reconstruction error: 12.14
# Epoch 29:	#####################################################	elapsed: 1.91s, reconstruction error: 12.15
# Epoch 30:	#####################################################	elapsed: 2.00s, reconstruction error: 12.00
# Epoch 31:	#####################################################	elapsed: 2.00s, reconstruction error: 11.89
# Epoch 32:	#####################################################	elapsed: 1.47s, reconstruction error: 11.86
# Epoch 33:	#####################################################	elapsed: 1.97s, reconstruction error: 11.68
# Epoch 34:	#####################################################	elapsed: 2.06s, reconstruction error: 11.75
# Epoch 35:	#####################################################	elapsed: 2.08s, reconstruction error: 11.66
# Epoch 36:	#####################################################	elapsed: 2.15s, reconstruction error: 11.63
# Epoch 37:	#####################################################	elapsed: 2.01s, reconstruction error: 11.44
# Epoch 38:	#####################################################	elapsed: 1.97s, reconstruction error: 11.70
# Epoch 39:	#####################################################	elapsed: 2.09s, reconstruction error: 11.40
# Epoch 40:	#####################################################	elapsed: 2.10s, reconstruction error: 11.27
# Epoch 41:	#####################################################	elapsed: 1.86s, reconstruction error: 11.44
# Epoch 42:	#####################################################	elapsed: 2.03s, reconstruction error: 11.24
# Epoch 43:	#####################################################	elapsed: 2.03s, reconstruction error: 11.25
# Epoch 44:	#####################################################	elapsed: 1.94s, reconstruction error: 11.19
# Epoch 45:	#####################################################	elapsed: 1.96s, reconstruction error: 11.19
# Epoch 46:	#####################################################	elapsed: 2.10s, reconstruction error: 11.21
# Epoch 47:	#####################################################	elapsed: 2.09s, reconstruction error: 10.99
# Epoch 48:	#####################################################	elapsed: 1.85s, reconstruction error: 10.99
# Epoch 49:	#####################################################	elapsed: 1.97s, reconstruction error: 11.13
# Training finished!

# %% [markdown]
# # 2. DBN Training

# %%
def propagate_up(dbn, layers_count, visible):
    for i in range(layers_count):
        visible = append_ones(sigmoid(visible @ dbn[i].W[:, :-1]))
    return visible

def propagate_down(dbn, layers_count, hidden):
    for i in reversed(range(layers_count)):
        hidden = append_ones(sigmoid(hidden @ np.transpose(dbn[i].W[:-1, :])))
    return hidden

# %% [markdown]
# ### DBN reconstruction error

# %%
def dbn_reconstuction_error(dbn, layers_count, minibatch):
    propagated = propagate_up(dbn, layers_count, minibatch)
    
    return reconstuction_error(dbn[layers_count], propagated)

# %% [markdown]
# ### Sampling in Deep Belief Networks

# %%
def sample_rbm(rbm, minibatch, steps):
    observations_count = minibatch.shape[0]

    visible = minibatch
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
    for cd_i in range(steps):
        hidden[:, :-1] = sigmoid(visible @ rbm.W[:, :-1])
        hidden[:, :-1] = (hidden[:, :-1] > rand(observations_count, rbm.hidden_size)).astype(np.float32)
    
        visible[:, :-1] = sigmoid(hidden @ np.transpose(rbm.W[:-1, :]))
        if cd_i < (steps - 1):
            visible[:, :-1] = (visible[:, :-1] > rand(observations_count, rbm.visible_size)).astype(np.float32)

    return visible

# %%
def sample_dbn(dbn, layer_idx, minibatch, steps):
    num_layers = len(dbn)
    
    sample = propagate_up(dbn, layer_idx, minibatch)
    sample = sample_rbm(dbn[layer_idx], sample, steps)
    sample = propagate_down(dbn, layer_idx, sample)
    
    return sample

# %%
def draw_layer_samples(dbn, layer_idx, minibatch, steps=200):
    samples = sample_dbn(dbn, layer_idx, minibatch, steps)
    tiles(np.reshape(samples[:, :-1], newshape=(-1, 16, 28, 28)))

# %% [markdown]
# ### Greedy layer-wise training

# %%
def train_dbn(dbn, layer_idx, dataset, batch_size):
    dataset = propagate_up(dbn, layer_idx, dataset)
    
    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(dbn[layer_idx], batch)
        if batch_idx % round(batches_limit / 50) == 0: print("#", end="")

# %%
BATCH_SIZE = 128
EPOCHS_COUNT = 50

LEARNING_RATE = 0.1
MOMENTUM = 0.5

DBN_HIDDEN_LAYER_SIZE = 200
dbn = [
    Rbm(VISIBLE_LAYER_SIZE, DBN_HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM),
    Rbm(DBN_HIDDEN_LAYER_SIZE, DBN_HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM),
    Rbm(DBN_HIDDEN_LAYER_SIZE, DBN_HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM)
]

for layer_idx in range(len(dbn)):
    print("\nLearning layer {}".format(layer_idx))

    for epoch in range(EPOCHS_COUNT):
        print("Epoch {}:".format(epoch),  end="\t")

        if epoch == 5:
            dbn[layer_idx].momentum = 0.8
        
        start_time = time.time()
        train_dbn(dbn, layer_idx, dataset, BATCH_SIZE)
        elapsed = time.time() - start_time
        
        error = dbn_reconstuction_error(dbn, layer_idx, monitoring_set)
        print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))
    
print("Training finished!")
# Out:
# Learning layer 0
# Epoch 0:	#####################################################	elapsed: 2.03s, reconstruction error: 30.59
# Epoch 1:	#####################################################	elapsed: 3.02s, reconstruction error: 23.99
# Epoch 2:	#####################################################	elapsed: 2.49s, reconstruction error: 21.01
# Epoch 3:	#####################################################	elapsed: 2.25s, reconstruction error: 18.88
# Epoch 4:	#####################################################	elapsed: 2.23s, reconstruction error: 17.18
# Epoch 5:	#####################################################	elapsed: 2.30s, reconstruction error: 16.04
# Epoch 6:	#####################################################	elapsed: 2.13s, reconstruction error: 15.33
# Epoch 7:	#####################################################	elapsed: 2.01s, reconstruction error: 14.69
# Epoch 8:	#####################################################	elapsed: 2.31s, reconstruction error: 14.28
# Epoch 9:	#####################################################	elapsed: 2.46s, reconstruction error: 13.70
# Epoch 10:	#####################################################	elapsed: 2.36s, reconstruction error: 13.22
# Epoch 11:	#####################################################	elapsed: 2.46s, reconstruction error: 12.98
# Epoch 12:	#####################################################	elapsed: 2.20s, reconstruction error: 12.67
# Epoch 13:	#####################################################	elapsed: 2.13s, reconstruction error: 12.34
# Epoch 14:	#####################################################	elapsed: 1.92s, reconstruction error: 11.96
# Epoch 15:	#####################################################	elapsed: 2.30s, reconstruction error: 11.81
# Epoch 16:	#####################################################	elapsed: 1.51s, reconstruction error: 11.65
# Epoch 17:	#####################################################	elapsed: 2.29s, reconstruction error: 11.38
# Epoch 18:	#####################################################	elapsed: 2.49s, reconstruction error: 11.25
# Epoch 19:	#####################################################	elapsed: 2.43s, reconstruction error: 10.91
# Epoch 20:	#####################################################	elapsed: 2.52s, reconstruction error: 10.89
# Epoch 21:	#####################################################	elapsed: 2.46s, reconstruction error: 10.84
# Epoch 22:	#####################################################	elapsed: 2.41s, reconstruction error: 10.67
# Epoch 23:	#####################################################	elapsed: 2.38s, reconstruction error: 10.39
# Epoch 24:	#####################################################	elapsed: 2.42s, reconstruction error: 10.54
# Epoch 25:	#####################################################	elapsed: 2.30s, reconstruction error: 10.40
# Epoch 26:	#####################################################	elapsed: 2.19s, reconstruction error: 10.23
# Epoch 27:	#####################################################	elapsed: 2.56s, reconstruction error: 10.14
# Epoch 28:	#####################################################	elapsed: 2.58s, reconstruction error: 10.07
# Epoch 29:	#####################################################	elapsed: 1.90s, reconstruction error: 10.06
# Epoch 30:	#####################################################	elapsed: 2.54s, reconstruction error: 9.92
# Epoch 31:	#####################################################	elapsed: 2.71s, reconstruction error: 9.87
# Epoch 32:	#####################################################	elapsed: 1.71s, reconstruction error: 9.93
# Epoch 33:	#####################################################	elapsed: 2.69s, reconstruction error: 9.79
# Epoch 34:	#####################################################	elapsed: 1.61s, reconstruction error: 9.73
# Epoch 35:	#####################################################	elapsed: 2.43s, reconstruction error: 9.52
# Epoch 36:	#####################################################	elapsed: 2.64s, reconstruction error: 9.59
# Epoch 37:	#####################################################	elapsed: 2.02s, reconstruction error: 9.61
# Epoch 38:	#####################################################	elapsed: 1.54s, reconstruction error: 9.40
# Epoch 39:	#####################################################	elapsed: 2.17s, reconstruction error: 9.50
# Epoch 40:	#####################################################	elapsed: 2.07s, reconstruction error: 9.39
# Epoch 41:	#####################################################	elapsed: 2.20s, reconstruction error: 9.43
# Epoch 42:	#####################################################	elapsed: 1.58s, reconstruction error: 9.41
# Epoch 43:	#####################################################	elapsed: 2.37s, reconstruction error: 9.20
# Epoch 44:	#####################################################	elapsed: 2.41s, reconstruction error: 9.31
# Epoch 45:	#####################################################	elapsed: 2.38s, reconstruction error: 9.23
# Epoch 46:	#####################################################	elapsed: 2.39s, reconstruction error: 9.34
# Epoch 47:	#####################################################	elapsed: 2.33s, reconstruction error: 9.16
# Epoch 48:	#####################################################	elapsed: 2.50s, reconstruction error: 9.03
# Epoch 49:	#####################################################	elapsed: 1.51s, reconstruction error: 9.24
#
# Learning layer 1
# Epoch 0:	#####################################################	elapsed: 1.20s, reconstruction error: 18.04
# Epoch 1:	#####################################################	elapsed: 1.19s, reconstruction error: 13.86
# Epoch 2:	#####################################################	elapsed: 1.15s, reconstruction error: 11.58
# Epoch 3:	#####################################################	elapsed: 1.26s, reconstruction error: 10.30
# Epoch 4:	#####################################################	elapsed: 1.16s, reconstruction error: 9.36
# Epoch 5:	#####################################################	elapsed: 1.18s, reconstruction error: 8.59
# Epoch 6:	#####################################################	elapsed: 1.26s, reconstruction error: 7.86
# Epoch 7:	#####################################################	elapsed: 1.40s, reconstruction error: 7.69
# Epoch 8:	#####################################################	elapsed: 0.69s, reconstruction error: 7.52
# Epoch 9:	#####################################################	elapsed: 1.01s, reconstruction error: 7.03
# Epoch 10:	#####################################################	elapsed: 1.11s, reconstruction error: 6.89
# Epoch 11:	#####################################################	elapsed: 0.77s, reconstruction error: 6.69
# Epoch 12:	#####################################################	elapsed: 0.92s, reconstruction error: 6.48
# Epoch 13:	#####################################################	elapsed: 0.62s, reconstruction error: 6.24
# Epoch 14:	#####################################################	elapsed: 0.74s, reconstruction error: 6.21
# Epoch 15:	#####################################################	elapsed: 0.67s, reconstruction error: 6.15
# Epoch 16:	#####################################################	elapsed: 0.69s, reconstruction error: 6.05
# Epoch 17:	#####################################################	elapsed: 0.75s, reconstruction error: 5.93
# Epoch 18:	#####################################################	elapsed: 0.71s, reconstruction error: 5.73
# Epoch 19:	#####################################################	elapsed: 0.74s, reconstruction error: 5.73
# Epoch 20:	#####################################################	elapsed: 0.83s, reconstruction error: 5.60
# Epoch 21:	#####################################################	elapsed: 0.83s, reconstruction error: 5.51
# Epoch 22:	#####################################################	elapsed: 0.74s, reconstruction error: 5.42
# Epoch 23:	#####################################################	elapsed: 0.92s, reconstruction error: 5.42
# Epoch 24:	#####################################################	elapsed: 1.28s, reconstruction error: 5.23
# Epoch 25:	#####################################################	elapsed: 1.13s, reconstruction error: 5.32
# Epoch 26:	#####################################################	elapsed: 1.29s, reconstruction error: 5.17
# Epoch 27:	#####################################################	elapsed: 0.90s, reconstruction error: 5.14
# Epoch 28:	#####################################################	elapsed: 0.74s, reconstruction error: 5.01
# Epoch 29:	#####################################################	elapsed: 1.47s, reconstruction error: 5.24
# Epoch 30:	#####################################################	elapsed: 0.76s, reconstruction error: 5.07
# Epoch 31:	#####################################################	elapsed: 0.64s, reconstruction error: 5.00
# Epoch 32:	#####################################################	elapsed: 1.06s, reconstruction error: 4.93
# Epoch 33:	#####################################################	elapsed: 0.91s, reconstruction error: 5.05
# Epoch 34:	#####################################################	elapsed: 1.25s, reconstruction error: 4.89
# Epoch 35:	#####################################################	elapsed: 1.29s, reconstruction error: 4.82
# Epoch 36:	#####################################################	elapsed: 0.76s, reconstruction error: 4.84
# Epoch 37:	#####################################################	elapsed: 0.98s, reconstruction error: 4.80
# Epoch 38:	#####################################################	elapsed: 1.19s, reconstruction error: 4.82
# Epoch 39:	#####################################################	elapsed: 1.16s, reconstruction error: 4.84
# Epoch 40:	#####################################################	elapsed: 1.13s, reconstruction error: 4.81
# Epoch 41:	#####################################################	elapsed: 0.74s, reconstruction error: 4.68
# Epoch 42:	#####################################################	elapsed: 0.74s, reconstruction error: 4.72
# Epoch 43:	#####################################################	elapsed: 0.76s, reconstruction error: 4.72
# Epoch 44:	#####################################################	elapsed: 1.09s, reconstruction error: 4.70
# Epoch 45:	#####################################################	elapsed: 0.65s, reconstruction error: 4.68
# Epoch 46:	#####################################################	elapsed: 1.17s, reconstruction error: 4.75
# Epoch 47:	#####################################################	elapsed: 0.73s, reconstruction error: 4.50
# Epoch 48:	#####################################################	elapsed: 0.69s, reconstruction error: 4.48
# Epoch 49:	#####################################################	elapsed: 1.12s, reconstruction error: 4.61
#
# Learning layer 2
# Epoch 0:	#####################################################	elapsed: 1.30s, reconstruction error: 12.80
# Epoch 1:	#####################################################	elapsed: 1.49s, reconstruction error: 9.67
# Epoch 2:	#####################################################	elapsed: 0.78s, reconstruction error: 7.72
# Epoch 3:	#####################################################	elapsed: 0.72s, reconstruction error: 6.86
# Epoch 4:	#####################################################	elapsed: 1.24s, reconstruction error: 5.97
# Epoch 5:	#####################################################	elapsed: 0.72s, reconstruction error: 5.55
# Epoch 6:	#####################################################	elapsed: 0.81s, reconstruction error: 5.27
# Epoch 7:	#####################################################	elapsed: 1.29s, reconstruction error: 4.93
# Epoch 8:	#####################################################	elapsed: 1.31s, reconstruction error: 4.80
# Epoch 9:	#####################################################	elapsed: 1.31s, reconstruction error: 4.55
# Epoch 10:	#####################################################	elapsed: 1.29s, reconstruction error: 4.39
# Epoch 11:	#####################################################	elapsed: 1.27s, reconstruction error: 4.18
# Epoch 12:	#####################################################	elapsed: 0.76s, reconstruction error: 4.05
# Epoch 13:	#####################################################	elapsed: 0.90s, reconstruction error: 4.05
# Epoch 14:	#####################################################	elapsed: 1.29s, reconstruction error: 4.10
# Epoch 15:	#####################################################	elapsed: 0.81s, reconstruction error: 4.11
# Epoch 16:	#####################################################	elapsed: 0.78s, reconstruction error: 3.81
# Epoch 17:	#####################################################	elapsed: 1.37s, reconstruction error: 3.67
# Epoch 18:	#####################################################	elapsed: 1.28s, reconstruction error: 3.78
# Epoch 19:	#####################################################	elapsed: 1.23s, reconstruction error: 3.69
# Epoch 20:	#####################################################	elapsed: 1.27s, reconstruction error: 3.73
# Epoch 21:	#####################################################	elapsed: 1.28s, reconstruction error: 3.62
# Epoch 22:	#####################################################	elapsed: 1.15s, reconstruction error: 3.62
# Epoch 23:	#####################################################	elapsed: 0.94s, reconstruction error: 3.66
# Epoch 24:	#####################################################	elapsed: 0.98s, reconstruction error: 3.49
# Epoch 25:	#####################################################	elapsed: 1.27s, reconstruction error: 3.42
# Epoch 26:	#####################################################	elapsed: 0.74s, reconstruction error: 3.61
# Epoch 27:	#####################################################	elapsed: 0.71s, reconstruction error: 3.49
# Epoch 28:	#####################################################	elapsed: 1.38s, reconstruction error: 3.54
# Epoch 29:	#####################################################	elapsed: 1.40s, reconstruction error: 3.45
# Epoch 30:	#####################################################	elapsed: 1.31s, reconstruction error: 3.46
# Epoch 31:	#####################################################	elapsed: 1.34s, reconstruction error: 3.46
# Epoch 32:	#####################################################	elapsed: 1.22s, reconstruction error: 3.40
# Epoch 33:	#####################################################	elapsed: 1.24s, reconstruction error: 3.37
# Epoch 34:	#####################################################	elapsed: 1.29s, reconstruction error: 3.25
# Epoch 35:	#####################################################	elapsed: 1.28s, reconstruction error: 3.33
# Epoch 36:	#####################################################	elapsed: 1.16s, reconstruction error: 3.33
# Epoch 37:	#####################################################	elapsed: 1.30s, reconstruction error: 3.24
# Epoch 38:	#####################################################	elapsed: 1.27s, reconstruction error: 3.30
# Epoch 39:	#####################################################	elapsed: 1.30s, reconstruction error: 3.19
# Epoch 40:	#####################################################	elapsed: 0.70s, reconstruction error: 3.26
# Epoch 41:	#####################################################	elapsed: 1.25s, reconstruction error: 3.23
# Epoch 42:	#####################################################	elapsed: 1.37s, reconstruction error: 3.20
# Epoch 43:	#####################################################	elapsed: 0.91s, reconstruction error: 3.29
# Epoch 44:	#####################################################	elapsed: 1.49s, reconstruction error: 3.23
# Epoch 45:	#####################################################	elapsed: 1.16s, reconstruction error: 3.19
# Epoch 46:	#####################################################	elapsed: 1.31s, reconstruction error: 3.21
# Epoch 47:	#####################################################	elapsed: 1.28s, reconstruction error: 3.15
# Epoch 48:	#####################################################	elapsed: 1.17s, reconstruction error: 3.17
# Epoch 49:	#####################################################	elapsed: 0.87s, reconstruction error: 3.22
# Training finished!

# %%
draw_layer_samples(dbn, 0, monitoring_set[:8*16])

# %%
draw_layer_samples(dbn, 1, monitoring_set[:8*16])

# %%
draw_layer_samples(dbn, 2, monitoring_set[:8*16])
