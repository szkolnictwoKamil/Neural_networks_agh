# %%
import numpy as np
import matplotlib.pyplot as plt
import time
# import mkl

# mkl.set_num_threads(2)
np.random.seed(1234)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]

# %% [markdown]
# ### Handy utility functions

# %%
def append_ones(matrix, axis=1):
    return np.concatenate((matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=axis)

def zeros(*dims):
    return np.zeros(shape=tuple(dims), dtype=np.float32)

def ones(*dims):
    return np.ones(shape=tuple(dims), dtype=np.float32)

def rand(*dims):
    return np.random.rand(*dims).astype(np.float32)

def randn(*dims):
    return np.random.randn(*dims).astype(np.float32)

def chunks(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

def as_matrix(vector):
    return np.reshape(vector, (-1, 1))

def one_hot_encode(labels):
    one_hot = zeros(labels.shape[0], np.max(labels) + 1) 
    one_hot[np.arange(labels.shape[0]), labels] = 1
    return one_hot.astype(np.float32)

def classify(mlp, batch):
    probabilities = forward_pass(mlp, batch, False)
    return np.argmax(probabilities, axis=1)

def tiles(examples):
    rows_count = examples.shape[0]
    cols_count = examples.shape[1]
    tile_height = examples.shape[2]
    tile_width = examples.shape[3]
    
    space_between_tiles = 2
    img_matrix = np.empty(shape=(rows_count * (tile_height + space_between_tiles) - space_between_tiles,  
                                 cols_count * (tile_width + space_between_tiles) - space_between_tiles))
    img_matrix.fill(np.nan)

    for r in range(rows_count):
        for c in range(cols_count):
            x_0 = r * (tile_height + space_between_tiles)
            y_0 = c * (tile_width + space_between_tiles)
            ex_min = np.min(examples[r, c])
            ex_max = np.max(examples[r, c])
            img_matrix[x_0:x_0 + tile_height, y_0:y_0 + tile_width] = (examples[r, c] - ex_min) / (ex_max - ex_min)
    
    plt.matshow(img_matrix, cmap='gray', interpolation='none')
    plt.axis('off')
    plt.show()

def draw_rbm_filters(rbm):
    filters = np.reshape(np.transpose(rbm.W)[:-1, :-1], newshape=(8, -1, 28, 28))
    tiles(filters)

def draw_layer_filters(layer):
    filters = np.reshape(layer.W[:-1].T, newshape=(8, -1, 28, 28))
    tiles(filters)

# %% [markdown]
# ### Activation functions

# %%
def sigmoid(batch, stochastic=False):
    activations = 1.0 / (1.0 + np.exp(-batch))
    if stochastic:
        return activations > rand(*activations.shape).astype(np.float32)
    else:
        return activations

def sigmoid_derivative(batch):
    s = sigmoid(batch)
    return s * (1.0 - s)

def softmax(batch):
    norm_batch = batch - np.max(batch, axis=-1, keepdims=True)
    numerator = np.exp(norm_batch)
    denominator = np.sum(numerator, axis=-1, keepdims=True)
    return numerator / denominator

# %% [markdown]
# # MNIST dataset

# %%
# !pip install mnist
# Out:
# Collecting mnist
#   Downloading mnist-0.2.2-py2.py3-none-any.whl (3.5 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from mnist) (1.21.6)
# Installing collected packages: mnist
# Successfully installed mnist-0.2.2

# %%
import mnist
digits = np.reshape(mnist.train_images()[:12*24], newshape=(12, 24, 28, 28))
tiles(digits)

# %% [markdown]
# # ReLU and Max-Norm regularization

# %%
def relu(batch, stochastic=False):
    if stochastic is True:
        return np.maximum(0, batch + np.random.normal(scale=np.sqrt(sigmoid(batch)), size=batch.shape))
    else:
        return np.maximum(0, batch)

def relu_derivative(batch):
    return np.where(batch <= 0, 0, 1)

# %%
def limit_weights(weights, limit):
    limits = ones(*weights.shape)
    col_norms = np.linalg.norm(weights, axis=0)
    limits[:, col_norms > limit] = limit / col_norms[col_norms > limit]
    return weights * limits

# %% [markdown]
# # RBM & DBN training

# %%
class Rbm:
    def __init__(self, visible_size, hidden_size, visible_act_func, hidden_act_func, 
                 learning_rate, momentum, weight_limit):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        
        self.visible_act_func = visible_act_func
        self.hidden_act_func = hidden_act_func
        
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.weight_limit = weight_limit
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size+1)).astype(np.float32)
        self.W[:, -1] = 0.0
        self.W[-1, :] = 0.0
        self.M = zeros(self.visible_size+1, self.hidden_size+1)

# %%
def cdk(rbm, minibatch, k=1):
    observations_count = minibatch.shape[0]

    positive_visible = minibatch
    negative_visible = append_ones(zeros(observations_count, rbm.visible_size))

    positive_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    negative_hidden = append_ones(zeros(observations_count, rbm.hidden_size))

    z = minibatch @ rbm.W[:, :-1]
    positive_hidden[:, :-1] = rbm.hidden_act_func(z)
    negative_hidden[:, :-1] = rbm.hidden_act_func(z, stochastic=True)

    for cd_i in range(k):
        negative_visible[:, :-1] = rbm.visible_act_func(negative_hidden @ rbm.W[:-1, :].T,
                                                        stochastic=True)
        z = negative_visible @ rbm.W[:, :-1]
        if cd_i < (k - 1):
            negative_hidden[:, :-1] = rbm.hidden_act_func(z, stochastic=True)
        else:
            negative_hidden[:, :-1] = rbm.hidden_act_func(z)

    rbm.M *= rbm.momentum
    rbm.M += (rbm.learning_rate / observations_count) * positive_visible.T @ positive_hidden
    rbm.M -= (rbm.learning_rate / observations_count) * negative_visible.T @ negative_hidden

    rbm.W += rbm.M;
    
    if rbm.weight_limit > 0.0:
        rbm.W[:-1, :-1] = limit_weights(rbm.W[:-1, :-1], rbm.weight_limit)

def reconstuction_error(rbm, minibatch):
    observations_count = minibatch.shape[0]
    visible = zeros(observations_count, rbm.visible_size)
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
    hidden[:, :-1] =  rbm.hidden_act_func(minibatch @ rbm.W[:, :-1], stochastic=True)
    visible = rbm.visible_act_func(hidden @ np.transpose(rbm.W[:-1, :]))
    
    error = minibatch[:, :-1] - visible
    error = np.sum(np.square(error)) / observations_count
    
    return error

# %%
def propagate_up(dbn, layers_count, visible):
    for i in range(layers_count):
        visible = append_ones(sigmoid(visible @ dbn[i].W[:, :-1]))
    return visible

def propagate_down(dbn, layers_count, hidden):
    for i in reversed(range(layers_count)):
        hidden = append_ones(sigmoid(hidden @ np.transpose(dbn[i].W[:-1, :])))
    return hidden

def dbn_reconstuction_error(dbn, layer_idx, minibatch):
    propagated = propagate_up(dbn, layer_idx, minibatch)
    return reconstuction_error(dbn[layer_idx], propagated)

def train_dbn_layer(dbn, layer_idx, dataset, batch_size):
    dataset = propagate_up(dbn, layer_idx, dataset)
    
    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(dbn[layer_idx], batch)
        if batch_idx % round(batches_limit / 40) == 0: print("#", end="")
            
def run_dbn_training(dbn, dataset, monitoring_set, batch_size, epochs_count, target_momentum=0.9):
    for layer_idx in range(len(dbn)):
        print("\nLearning layer {}".format(layer_idx+1))

        for epoch in range(epochs_count):
            print("Epoch {}:".format(epoch+1),  end="\t")

            if epoch == 5:
                dbn[layer_idx].momentum = target_momentum

            start_time = time.time()
            train_dbn_layer(dbn, layer_idx, dataset, batch_size)
            elapsed = time.time() - start_time

            error = dbn_reconstuction_error(dbn, layer_idx, monitoring_set)
            print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))

# %% [markdown]
# # MLP training

# %%
class Layer:
    def __init__(self, visible_size, hidden_size, activation_fun, d_activation_fun, 
                 learning_rate, momentum, weight_limit):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        
        self.activation_fun = activation_fun
        self.d_activation_fun = d_activation_fun
                
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.weight_limit = weight_limit
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size)).astype(np.float32)
        self.W[-1, :] = 0.0
        
        self.activations = None
        self.d_activations = None
        self.deltas = None

        self.M = zeros(self.visible_size+1, self.hidden_size)

# %% [markdown]
# ### Forward pass

# %%
def forward_pass(mlp, batch, compute_derivatives):
    visible = batch
    
    for layer_idx, layer in enumerate(mlp):
        z = visible @ layer.W
        layer.activations = append_ones(layer.activation_fun(z))
        
        if compute_derivatives and (layer_idx < len(mlp) - 1):
            layer.d_activations = layer.d_activation_fun(z)
        
        visible = layer.activations
        
    return visible[:, :-1]

# %% [markdown]
# ### Error backpropagation

# %%
def error_backpropagate(mlp, batch):
    observations_count = batch.shape[0]
    
    for layer_idx, layer in reversed(list(enumerate(mlp))):
        if layer_idx > 0:
            prev_layer = mlp[layer_idx - 1]
            visible = prev_layer.activations
            
            prev_layer.deltas = (layer.deltas @ layer.W[:-1].T) * prev_layer.d_activations
        else:
            visible = batch
        
        gradient = (visible.T @ layer.deltas) / observations_count        
        
        layer.M = layer.momentum * layer.M - layer.learning_rate * gradient
        layer.W += layer.M
        
        if layer.weight_limit > 0.0:
            layer.W[:-1, :] = limit_weights(layer.W[:-1, :], layer.weight_limit)

# %% [markdown]
# ### Training procedure

# %%
def train_mlp(mlp, dataset, labels, batch_size):
    batches_limit = dataset.shape[0] / batch_size
    
    batched_data = chunks(dataset, batch_size)
    batched_labels = chunks(labels, batch_size)
    
    for batch_idx, (batch, batch_labels) in enumerate(zip(batched_data, batched_labels)):
        # Forward pass: compute activatations and derivatives of activations
        y = forward_pass(mlp, batch, True)
        
        mlp[-1].deltas = y - batch_labels

        
        # Once softmax deltas are set, we may backpropagate errors
        error_backpropagate(mlp, batch)
        
        if batch_idx % round(batches_limit / 40) == 0: print("#", end="")

# %%
def run_mlp_training(mlp, train_set, train_labels, validation_set, validation_labels,
                     batch_size, epochs_count, target_momentum=0.95):
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch+1),  end="\t")
        
        if epoch == 5:
            for layer in mlp: layer.momentum = target_momentum
        
        start_time = time.time()
        train_mlp(mlp, train_set, train_labels, batch_size)
        elapsed = time.time() - start_time

        predictions = classify(mlp, validation_set)
        accuracy = 100.0 * np.sum(predictions == validation_labels) / predictions.shape[0]
        print("\telapsed: {0:>2.2f}s, accuracy: {1:>2.2f}".format(elapsed, accuracy))

    print("Training finished!")

# %% [markdown]
# #  Initializing MLP with DBN weights
#
# Implement initialization of MLP weights (and biases) using weights (and biases) from the DBN layers.
#
# Make sure that the MLP weights (and biases) are **copies** of the DBN weights (and biases). You can use ```np.copy(...)``` function to copy the weights (simple assignment will make a view instead of a copy).

# %%
def initialize_mlp(mlp, dbn):
  for layer_idx in range(len(dbn)):
    mlp[layer_idx].W = np.copy(dbn[layer_idx].W[:, :-1])

# %% [markdown]
# # MNIST digits classification

# %%
DATASET_SIZE = 10000 # 60000 for whole dataset
DIGIT_SIZE = 28

##### Train set #####

mnist_train_images = mnist.train_images().astype(np.float32) / 255.0
mnist_train_labels = mnist.train_labels()

order = np.random.permutation(len(mnist_train_images))
mnist_train_images = mnist_train_images[order]
mnist_train_labels = mnist_train_labels[order]

mnist_train_images = np.reshape(mnist_train_images[:DATASET_SIZE],
                                newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
mnist_train_images = append_ones(mnist_train_images)

mnist_train_labels = mnist_train_labels[:DATASET_SIZE]
mnist_train_labels = one_hot_encode(mnist_train_labels)

monitoring_set_indeces = np.random.choice(mnist_train_images.shape[0], 512, replace=False)
monitoring_set = mnist_train_images[monitoring_set_indeces]

##### Test set #####

mnist_test_images = mnist.test_images().astype(np.float32) / 255.0
mnist_test_images = np.reshape(mnist_test_images, newshape=(-1, DIGIT_SIZE*DIGIT_SIZE))
mnist_test_images = append_ones(mnist_test_images)

mnist_test_labels = mnist.test_labels()

# %%
VISIBLE_LAYER_SIZE = DIGIT_SIZE*DIGIT_SIZE
HIDDEN_LAYER_SIZE = 256

BATCH_SIZE = 128
EPOCHS_COUNT = 50

MLP_LEARNING_RATE = 0.03
SOFTMAX_LEARNING_RATE = 0.15
RBM_LEARNING_RATE = 0.003
MOMENTUM = 0.5

# %% [markdown]
# ### Plain vs pretrained comparison

# %%
from IPython.core.display import HTML

def compare_pretraining_results(mlp, dbn,
                                train_set, train_labels,
                                validation_set, validation_labels,
                                monitoring_set,
                                batch_size, epochs_count):
    for layer in mlp:
        layer.reset()

    display(HTML('<h3>Plain MLP training</h3>'))
    run_mlp_training(mlp,
                     train_set, train_labels,
                     validation_set, validation_labels,
                     batch_size, epochs_count)
    
    display(HTML('<h3>Input layer filters in the plain MLP</h3>'))
    draw_layer_filters(mlp[0])
    
    display(HTML('<h3>Largest norms of weight-vectors in the plain MLP layers</h3>'))
    for i, layer in enumerate(mlp):
        max_norm = np.max(np.linalg.norm(layer.W[:-1, :], axis=0))
        print('\tlayer {0}: {1:.2f}'.format(i+1, max_norm))
    
    display(HTML('<h3>DBN training</h3>'))
    run_dbn_training(dbn, train_set, monitoring_set, batch_size, epochs_count)
    
    for layer in mlp:
        layer.reset()
    
    initialize_mlp(mlp, dbn)
    
    display(HTML('<h3>Finetuning pretrained MLP</h3>'))
    run_mlp_training(mlp,
                     train_set, train_labels,
                     validation_set, validation_labels,
                     batch_size, epochs_count)
    
    display(HTML('<h3>First layer filters in the DBN</h3>'))
    draw_rbm_filters(dbn[0])
    
    display(HTML('<h3>Input layer filters in the pretrained & finetuned MLP</h3>'))
    draw_layer_filters(mlp[0])

    display(HTML('<h3>Largest norms of weight-vectors in the finetuned MLP layers</h3>'))
    for i, layer in enumerate(mlp):
        max_norm = np.max(np.linalg.norm(layer.W[:-1, :], axis=0))
        print('\tlayer {0}: {1:.2f}'.format(i+1, max_norm))

# %% [markdown]
# ### Shallow ReLU network

# %%
shallow_mlp = [
    Layer(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu_derivative, MLP_LEARNING_RATE, MOMENTUM,
          weight_limit=2.0),
    Layer(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu_derivative, MLP_LEARNING_RATE, MOMENTUM,
          weight_limit=1.0),
    Layer(HIDDEN_LAYER_SIZE, 10, softmax, None, SOFTMAX_LEARNING_RATE, MOMENTUM,
          weight_limit=4.0)
]

shallow_dbn = [
    Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, sigmoid, relu, RBM_LEARNING_RATE, MOMENTUM,
        weight_limit=2.0),
    Rbm(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu, RBM_LEARNING_RATE, MOMENTUM,
        weight_limit=1.0)
]

compare_pretraining_results(shallow_mlp, shallow_dbn,
                            mnist_train_images, mnist_train_labels,
                            mnist_test_images, mnist_test_labels,
                            monitoring_set,
                            BATCH_SIZE, EPOCHS_COUNT)
# Out:
# <h3>Plain MLP training</h3>
# Epoch 1:	########################################	elapsed: 1.06s, accuracy: 11.35
# Epoch 2:	########################################	elapsed: 1.04s, accuracy: 36.42
# Epoch 3:	########################################	elapsed: 1.04s, accuracy: 63.44
# Epoch 4:	########################################	elapsed: 1.00s, accuracy: 74.00
# Epoch 5:	########################################	elapsed: 1.01s, accuracy: 79.39
# Epoch 6:	########################################	elapsed: 1.04s, accuracy: 89.53
# Epoch 7:	########################################	elapsed: 1.03s, accuracy: 92.21
# Epoch 8:	########################################	elapsed: 1.02s, accuracy: 93.57
# Epoch 9:	########################################	elapsed: 1.08s, accuracy: 92.15
# Epoch 10:	########################################	elapsed: 1.04s, accuracy: 94.58
# Epoch 11:	########################################	elapsed: 1.03s, accuracy: 93.75
# Epoch 12:	########################################	elapsed: 1.05s, accuracy: 95.25
# Epoch 13:	########################################	elapsed: 1.03s, accuracy: 94.23
# Epoch 14:	########################################	elapsed: 1.04s, accuracy: 94.84
# Epoch 15:	########################################	elapsed: 1.05s, accuracy: 94.69
# Epoch 16:	########################################	elapsed: 1.02s, accuracy: 95.45
# Epoch 17:	########################################	elapsed: 1.03s, accuracy: 95.79
# Epoch 18:	########################################	elapsed: 1.04s, accuracy: 95.61
# Epoch 19:	########################################	elapsed: 1.01s, accuracy: 96.33
# Epoch 20:	########################################	elapsed: 1.02s, accuracy: 96.19
# Epoch 21:	########################################	elapsed: 1.04s, accuracy: 95.94
# Epoch 22:	########################################	elapsed: 1.02s, accuracy: 96.42
# Epoch 23:	########################################	elapsed: 1.03s, accuracy: 96.49
# Epoch 24:	########################################	elapsed: 1.16s, accuracy: 96.62
# Epoch 25:	########################################	elapsed: 1.25s, accuracy: 96.66
# Epoch 26:	########################################	elapsed: 1.04s, accuracy: 96.69
# Epoch 27:	########################################	elapsed: 1.26s, accuracy: 96.67
# Epoch 28:	########################################	elapsed: 1.56s, accuracy: 96.68
# Epoch 29:	########################################	elapsed: 1.02s, accuracy: 96.67
# Epoch 30:	########################################	elapsed: 1.03s, accuracy: 96.69
# Epoch 31:	########################################	elapsed: 1.05s, accuracy: 96.68
# Epoch 32:	########################################	elapsed: 1.01s, accuracy: 96.68
# Epoch 33:	########################################	elapsed: 1.02s, accuracy: 96.69
# Epoch 34:	########################################	elapsed: 1.06s, accuracy: 96.69
# Epoch 35:	########################################	elapsed: 1.03s, accuracy: 96.71
# Epoch 36:	########################################	elapsed: 1.03s, accuracy: 96.71
# Epoch 37:	########################################	elapsed: 1.02s, accuracy: 96.70
# Epoch 38:	########################################	elapsed: 1.03s, accuracy: 96.72
# Epoch 39:	########################################	elapsed: 1.04s, accuracy: 96.72
# Epoch 40:	########################################	elapsed: 1.03s, accuracy: 96.72
# Epoch 41:	########################################	elapsed: 1.03s, accuracy: 96.72
# Epoch 42:	########################################	elapsed: 1.03s, accuracy: 96.72
# Epoch 43:	########################################	elapsed: 1.06s, accuracy: 96.71
# Epoch 44:	########################################	elapsed: 1.04s, accuracy: 96.71
# Epoch 45:	########################################	elapsed: 1.03s, accuracy: 96.72
# Epoch 46:	########################################	elapsed: 1.03s, accuracy: 96.73
# Epoch 47:	########################################	elapsed: 1.04s, accuracy: 96.72
# Epoch 48:	########################################	elapsed: 1.04s, accuracy: 96.74
# Epoch 49:	########################################	elapsed: 1.04s, accuracy: 96.74
# Epoch 50:	########################################	elapsed: 1.02s, accuracy: 96.74
# Training finished!
# <h3>Input layer filters in the plain MLP</h3>
# <h3>Largest norms of weight-vectors in the plain MLP layers</h3>
# 	layer 1: 1.78
# 	layer 2: 1.00
# 	layer 3: 4.00
# <h3>DBN training</h3>
# Learning layer 1
# Epoch 1:	########################################	elapsed: 1.32s, reconstruction error: 75.72
# Epoch 2:	########################################	elapsed: 1.31s, reconstruction error: 55.57
# Epoch 3:	########################################	elapsed: 1.26s, reconstruction error: 42.85
# Epoch 4:	########################################	elapsed: 1.88s, reconstruction error: 36.37
# Epoch 5:	########################################	elapsed: 1.27s, reconstruction error: 32.53
# Epoch 6:	########################################	elapsed: 1.29s, reconstruction error: 24.66
# Epoch 7:	########################################	elapsed: 1.28s, reconstruction error: 20.87
# Epoch 8:	########################################	elapsed: 1.27s, reconstruction error: 18.33
# Epoch 9:	########################################	elapsed: 1.37s, reconstruction error: 16.74
# Epoch 10:	########################################	elapsed: 1.33s, reconstruction error: 15.48
# Epoch 11:	########################################	elapsed: 1.31s, reconstruction error: 14.37
# Epoch 12:	########################################	elapsed: 1.28s, reconstruction error: 13.58
# Epoch 13:	########################################	elapsed: 1.28s, reconstruction error: 12.88
# Epoch 14:	########################################	elapsed: 1.31s, reconstruction error: 12.19
# Epoch 15:	########################################	elapsed: 1.30s, reconstruction error: 11.75
# Epoch 16:	########################################	elapsed: 1.32s, reconstruction error: 11.26
# Epoch 17:	########################################	elapsed: 1.36s, reconstruction error: 10.82
# Epoch 18:	########################################	elapsed: 1.33s, reconstruction error: 10.47
# Epoch 19:	########################################	elapsed: 1.32s, reconstruction error: 10.28
# Epoch 20:	########################################	elapsed: 1.33s, reconstruction error: 9.95
# Epoch 21:	########################################	elapsed: 1.32s, reconstruction error: 9.76
# Epoch 22:	########################################	elapsed: 1.29s, reconstruction error: 9.60
# Epoch 23:	########################################	elapsed: 1.33s, reconstruction error: 9.34
# Epoch 24:	########################################	elapsed: 1.38s, reconstruction error: 9.20
# Epoch 25:	########################################	elapsed: 1.33s, reconstruction error: 9.16
# Epoch 26:	########################################	elapsed: 1.34s, reconstruction error: 9.00
# Epoch 27:	########################################	elapsed: 1.36s, reconstruction error: 8.85
# Epoch 28:	########################################	elapsed: 1.33s, reconstruction error: 8.76
# Epoch 29:	########################################	elapsed: 1.33s, reconstruction error: 8.68
# Epoch 30:	########################################	elapsed: 1.36s, reconstruction error: 8.59
# Epoch 31:	########################################	elapsed: 1.32s, reconstruction error: 8.58
# Epoch 32:	########################################	elapsed: 1.37s, reconstruction error: 8.50
# Epoch 33:	########################################	elapsed: 1.35s, reconstruction error: 8.49
# Epoch 34:	########################################	elapsed: 1.34s, reconstruction error: 8.44
# Epoch 35:	########################################	elapsed: 1.36s, reconstruction error: 8.32
# Epoch 36:	########################################	elapsed: 1.33s, reconstruction error: 8.23
# Epoch 37:	########################################	elapsed: 1.36s, reconstruction error: 8.21
# Epoch 38:	########################################	elapsed: 1.36s, reconstruction error: 8.16
# Epoch 39:	########################################	elapsed: 1.37s, reconstruction error: 8.09
# Epoch 40:	########################################	elapsed: 1.32s, reconstruction error: 8.05
# Epoch 41:	########################################	elapsed: 1.34s, reconstruction error: 8.15
# Epoch 42:	########################################	elapsed: 1.30s, reconstruction error: 8.12
# Epoch 43:	########################################	elapsed: 1.29s, reconstruction error: 7.99
# Epoch 44:	########################################	elapsed: 1.31s, reconstruction error: 7.95
# Epoch 45:	########################################	elapsed: 1.32s, reconstruction error: 7.98
# Epoch 46:	########################################	elapsed: 1.29s, reconstruction error: 7.94
# Epoch 47:	########################################	elapsed: 1.37s, reconstruction error: 7.98
# Epoch 48:	########################################	elapsed: 1.35s, reconstruction error: 7.96
# Epoch 49:	########################################	elapsed: 1.34s, reconstruction error: 7.87
# Epoch 50:	########################################	elapsed: 1.35s, reconstruction error: 7.91
#
# Learning layer 2
# Epoch 1:	########################################	elapsed: 0.97s, reconstruction error: 25.92
# Epoch 2:	########################################	elapsed: 0.96s, reconstruction error: 22.78
# Epoch 3:	########################################	elapsed: 0.93s, reconstruction error: 20.37
# Epoch 4:	########################################	elapsed: 0.96s, reconstruction error: 19.30
# Epoch 5:	########################################	elapsed: 0.96s, reconstruction error: 19.44
# Epoch 6:	########################################	elapsed: 0.96s, reconstruction error: 17.64
# Epoch 7:	########################################	elapsed: 0.94s, reconstruction error: 18.31
# Epoch 8:	########################################	elapsed: 0.95s, reconstruction error: 16.55
# Epoch 9:	########################################	elapsed: 0.95s, reconstruction error: 16.19
# Epoch 10:	########################################	elapsed: 0.95s, reconstruction error: 15.46
# Epoch 11:	########################################	elapsed: 0.95s, reconstruction error: 14.80
# Epoch 12:	########################################	elapsed: 0.94s, reconstruction error: 13.95
# Epoch 13:	########################################	elapsed: 0.95s, reconstruction error: 15.59
# Epoch 14:	########################################	elapsed: 0.95s, reconstruction error: 14.93
# Epoch 15:	########################################	elapsed: 0.96s, reconstruction error: 14.51
# Epoch 16:	########################################	elapsed: 0.96s, reconstruction error: 15.09
# Epoch 17:	########################################	elapsed: 0.94s, reconstruction error: 14.43
# Epoch 18:	########################################	elapsed: 0.96s, reconstruction error: 14.56
# Epoch 19:	########################################	elapsed: 0.94s, reconstruction error: 13.97
# Epoch 20:	########################################	elapsed: 0.95s, reconstruction error: 13.56
# Epoch 21:	########################################	elapsed: 0.94s, reconstruction error: 13.60
# Epoch 22:	########################################	elapsed: 0.95s, reconstruction error: 14.41
# Epoch 23:	########################################	elapsed: 0.94s, reconstruction error: 13.36
# Epoch 24:	########################################	elapsed: 0.96s, reconstruction error: 13.30
# Epoch 25:	########################################	elapsed: 0.96s, reconstruction error: 13.42
# Epoch 26:	########################################	elapsed: 0.94s, reconstruction error: 13.29
# Epoch 27:	########################################	elapsed: 0.96s, reconstruction error: 13.25
# Epoch 28:	########################################	elapsed: 0.95s, reconstruction error: 12.85
# Epoch 29:	########################################	elapsed: 0.96s, reconstruction error: 14.11
# Epoch 30:	########################################	elapsed: 0.94s, reconstruction error: 14.64
# Epoch 31:	########################################	elapsed: 0.93s, reconstruction error: 12.84
# Epoch 32:	########################################	elapsed: 0.93s, reconstruction error: 13.17
# Epoch 33:	########################################	elapsed: 0.94s, reconstruction error: 13.16
# Epoch 34:	########################################	elapsed: 0.96s, reconstruction error: 13.40
# Epoch 35:	########################################	elapsed: 0.96s, reconstruction error: 13.36
# Epoch 36:	########################################	elapsed: 0.96s, reconstruction error: 13.16
# Epoch 37:	########################################	elapsed: 0.93s, reconstruction error: 12.43
# Epoch 38:	########################################	elapsed: 0.94s, reconstruction error: 12.83
# Epoch 39:	########################################	elapsed: 0.94s, reconstruction error: 12.94
# Epoch 40:	########################################	elapsed: 0.95s, reconstruction error: 13.25
# Epoch 41:	########################################	elapsed: 0.96s, reconstruction error: 13.06
# Epoch 42:	########################################	elapsed: 0.96s, reconstruction error: 13.37
# Epoch 43:	########################################	elapsed: 0.97s, reconstruction error: 13.36
# Epoch 44:	########################################	elapsed: 0.96s, reconstruction error: 13.06
# Epoch 45:	########################################	elapsed: 0.96s, reconstruction error: 13.18
# Epoch 46:	########################################	elapsed: 0.97s, reconstruction error: 12.60
# Epoch 47:	########################################	elapsed: 1.00s, reconstruction error: 12.81
# Epoch 48:	########################################	elapsed: 0.96s, reconstruction error: 12.83
# Epoch 49:	########################################	elapsed: 0.93s, reconstruction error: 12.74
# Epoch 50:	########################################	elapsed: 0.94s, reconstruction error: 12.97
# <h3>Finetuning pretrained MLP</h3>
# Epoch 1:	########################################	elapsed: 1.19s, accuracy: 92.34
# Epoch 2:	########################################	elapsed: 1.09s, accuracy: 94.43
# Epoch 3:	########################################	elapsed: 1.08s, accuracy: 95.10
# Epoch 4:	########################################	elapsed: 1.12s, accuracy: 96.18
# Epoch 5:	########################################	elapsed: 1.08s, accuracy: 96.21
# Epoch 6:	########################################	elapsed: 1.07s, accuracy: 96.21
# Epoch 7:	########################################	elapsed: 1.07s, accuracy: 96.39
# Epoch 8:	########################################	elapsed: 1.08s, accuracy: 96.73
# Epoch 9:	########################################	elapsed: 1.10s, accuracy: 96.94
# Epoch 10:	########################################	elapsed: 1.09s, accuracy: 96.73
# Epoch 11:	########################################	elapsed: 1.06s, accuracy: 96.76
# Epoch 12:	########################################	elapsed: 1.08s, accuracy: 97.03
# Epoch 13:	########################################	elapsed: 1.09s, accuracy: 97.06
# Epoch 14:	########################################	elapsed: 1.07s, accuracy: 97.03
# Epoch 15:	########################################	elapsed: 1.06s, accuracy: 97.14
# Epoch 16:	########################################	elapsed: 1.05s, accuracy: 97.12
# Epoch 17:	########################################	elapsed: 1.09s, accuracy: 97.40
# Epoch 18:	########################################	elapsed: 1.06s, accuracy: 97.39
# Epoch 19:	########################################	elapsed: 1.05s, accuracy: 97.39
# Epoch 20:	########################################	elapsed: 1.06s, accuracy: 97.41
# Epoch 21:	########################################	elapsed: 1.05s, accuracy: 97.40
# Epoch 22:	########################################	elapsed: 1.07s, accuracy: 97.42
# Epoch 23:	########################################	elapsed: 1.04s, accuracy: 97.42
# Epoch 24:	########################################	elapsed: 1.05s, accuracy: 97.39
# Epoch 25:	########################################	elapsed: 1.04s, accuracy: 97.40
# Epoch 26:	########################################	elapsed: 1.03s, accuracy: 97.39
# Epoch 27:	########################################	elapsed: 1.02s, accuracy: 97.39
# Epoch 28:	########################################	elapsed: 1.05s, accuracy: 97.40
# Epoch 29:	########################################	elapsed: 1.11s, accuracy: 97.41
# Epoch 30:	########################################	elapsed: 1.11s, accuracy: 97.41
# Epoch 31:	########################################	elapsed: 1.08s, accuracy: 97.43
# Epoch 32:	########################################	elapsed: 1.12s, accuracy: 97.41
# Epoch 33:	########################################	elapsed: 1.10s, accuracy: 97.42
# Epoch 34:	########################################	elapsed: 1.14s, accuracy: 97.40
# Epoch 35:	########################################	elapsed: 1.10s, accuracy: 97.41
# Epoch 36:	########################################	elapsed: 1.14s, accuracy: 97.41
# Epoch 37:	########################################	elapsed: 1.12s, accuracy: 97.42
# Epoch 38:	########################################	elapsed: 1.13s, accuracy: 97.42
# Epoch 39:	########################################	elapsed: 1.16s, accuracy: 97.40
# Epoch 40:	########################################	elapsed: 1.16s, accuracy: 97.39
# Epoch 41:	########################################	elapsed: 1.13s, accuracy: 97.38
# Epoch 42:	########################################	elapsed: 1.18s, accuracy: 97.38
# Epoch 43:	########################################	elapsed: 1.18s, accuracy: 97.38
# Epoch 44:	########################################	elapsed: 1.16s, accuracy: 97.38
# Epoch 45:	########################################	elapsed: 1.12s, accuracy: 97.38
# Epoch 46:	########################################	elapsed: 1.11s, accuracy: 97.38
# Epoch 47:	########################################	elapsed: 1.09s, accuracy: 97.37
# Epoch 48:	########################################	elapsed: 1.09s, accuracy: 97.37
# Epoch 49:	########################################	elapsed: 1.14s, accuracy: 97.38
# Epoch 50:	########################################	elapsed: 1.17s, accuracy: 97.38
# Training finished!
# <h3>First layer filters in the DBN</h3>
# <h3>Input layer filters in the pretrained & finetuned MLP</h3>
# <h3>Largest norms of weight-vectors in the finetuned MLP layers</h3>
# 	layer 1: 2.00
# 	layer 2: 1.00
# 	layer 3: 4.00

# %% [markdown]
# ### Deep ReLU network

# %%
deep_mlp = [
    Layer(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu_derivative, MLP_LEARNING_RATE, MOMENTUM,
          weight_limit=2.0),
    Layer(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu_derivative, MLP_LEARNING_RATE, MOMENTUM,
          weight_limit=1.0),
    Layer(HIDDEN_LAYER_SIZE, 2 * HIDDEN_LAYER_SIZE, relu, relu_derivative, MLP_LEARNING_RATE, MOMENTUM,
          weight_limit=1.0),
    Layer(2 * HIDDEN_LAYER_SIZE, 10, softmax, None, SOFTMAX_LEARNING_RATE, MOMENTUM,
          weight_limit=4.0)
]

deep_dbn = [
    Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, sigmoid, relu, RBM_LEARNING_RATE, MOMENTUM,
        weight_limit=2.0),
    Rbm(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu, RBM_LEARNING_RATE, MOMENTUM,
        weight_limit=1.0),
    Rbm(HIDDEN_LAYER_SIZE, 2 * HIDDEN_LAYER_SIZE, relu, relu, RBM_LEARNING_RATE, MOMENTUM,
        weight_limit=1.0)
]

compare_pretraining_results(deep_mlp, deep_dbn,
                            mnist_train_images, mnist_train_labels,
                            mnist_test_images, mnist_test_labels,
                            monitoring_set,
                            BATCH_SIZE, EPOCHS_COUNT)
# Out:
# <h3>Plain MLP training</h3>
# Epoch 1:	########################################	elapsed: 3.09s, accuracy: 11.35
# Epoch 2:	########################################	elapsed: 1.65s, accuracy: 11.35
# Epoch 3:	########################################	elapsed: 1.69s, accuracy: 11.35
# Epoch 4:	########################################	elapsed: 1.69s, accuracy: 11.35
# Epoch 5:	########################################	elapsed: 1.64s, accuracy: 11.35
# Epoch 6:	########################################	elapsed: 1.65s, accuracy: 44.51
# Epoch 7:	########################################	elapsed: 1.67s, accuracy: 80.05
# Epoch 8:	########################################	elapsed: 1.63s, accuracy: 90.21
# Epoch 9:	########################################	elapsed: 1.63s, accuracy: 92.09
# Epoch 10:	########################################	elapsed: 1.66s, accuracy: 92.80
# Epoch 11:	########################################	elapsed: 1.66s, accuracy: 92.98
# Epoch 12:	########################################	elapsed: 1.61s, accuracy: 93.57
# Epoch 13:	########################################	elapsed: 1.63s, accuracy: 92.98
# Epoch 14:	########################################	elapsed: 1.72s, accuracy: 93.79
# Epoch 15:	########################################	elapsed: 1.67s, accuracy: 93.74
# Epoch 16:	########################################	elapsed: 1.67s, accuracy: 94.44
# Epoch 17:	########################################	elapsed: 1.63s, accuracy: 94.09
# Epoch 18:	########################################	elapsed: 1.65s, accuracy: 95.12
# Epoch 19:	########################################	elapsed: 1.59s, accuracy: 95.56
# Epoch 20:	########################################	elapsed: 1.55s, accuracy: 95.60
# Epoch 21:	########################################	elapsed: 1.56s, accuracy: 95.59
# Epoch 22:	########################################	elapsed: 1.53s, accuracy: 95.41
# Epoch 23:	########################################	elapsed: 1.55s, accuracy: 95.32
# Epoch 24:	########################################	elapsed: 1.54s, accuracy: 95.99
# Epoch 25:	########################################	elapsed: 1.62s, accuracy: 96.34
# Epoch 26:	########################################	elapsed: 1.58s, accuracy: 95.46
# Epoch 27:	########################################	elapsed: 1.55s, accuracy: 96.24
# Epoch 28:	########################################	elapsed: 1.50s, accuracy: 96.45
# Epoch 29:	########################################	elapsed: 1.55s, accuracy: 96.75
# Epoch 30:	########################################	elapsed: 1.58s, accuracy: 96.77
# Epoch 31:	########################################	elapsed: 1.59s, accuracy: 96.78
# Epoch 32:	########################################	elapsed: 1.55s, accuracy: 96.77
# Epoch 33:	########################################	elapsed: 1.56s, accuracy: 96.79
# Epoch 34:	########################################	elapsed: 1.54s, accuracy: 96.79
# Epoch 35:	########################################	elapsed: 1.56s, accuracy: 96.79
# Epoch 36:	########################################	elapsed: 1.51s, accuracy: 96.81
# Epoch 37:	########################################	elapsed: 1.54s, accuracy: 96.82
# Epoch 38:	########################################	elapsed: 1.59s, accuracy: 96.80
# Epoch 39:	########################################	elapsed: 1.51s, accuracy: 96.80
# Epoch 40:	########################################	elapsed: 1.58s, accuracy: 96.80
# Epoch 41:	########################################	elapsed: 1.59s, accuracy: 96.80
# Epoch 42:	########################################	elapsed: 1.51s, accuracy: 96.80
# Epoch 43:	########################################	elapsed: 1.54s, accuracy: 96.80
# Epoch 44:	########################################	elapsed: 1.53s, accuracy: 96.80
# Epoch 45:	########################################	elapsed: 1.56s, accuracy: 96.80
# Epoch 46:	########################################	elapsed: 1.53s, accuracy: 96.81
# Epoch 47:	########################################	elapsed: 1.54s, accuracy: 96.81
# Epoch 48:	########################################	elapsed: 1.58s, accuracy: 96.80
# Epoch 49:	########################################	elapsed: 1.64s, accuracy: 96.80
# Epoch 50:	########################################	elapsed: 1.61s, accuracy: 96.80
# Training finished!
# <h3>Input layer filters in the plain MLP</h3>
# <h3>Largest norms of weight-vectors in the plain MLP layers</h3>
# 	layer 1: 2.00
# 	layer 2: 1.00
# 	layer 3: 0.83
# 	layer 4: 4.00
# <h3>DBN training</h3>
# Learning layer 1
# Epoch 1:	########################################	elapsed: 1.72s, reconstruction error: 75.51
# Epoch 2:	########################################	elapsed: 1.61s, reconstruction error: 54.83
# Epoch 3:	########################################	elapsed: 1.63s, reconstruction error: 42.26
# Epoch 4:	########################################	elapsed: 1.63s, reconstruction error: 36.07
# Epoch 5:	########################################	elapsed: 1.62s, reconstruction error: 32.62
# Epoch 6:	########################################	elapsed: 1.63s, reconstruction error: 24.80
# Epoch 7:	########################################	elapsed: 1.64s, reconstruction error: 20.85
# Epoch 8:	########################################	elapsed: 1.65s, reconstruction error: 18.55
# Epoch 9:	########################################	elapsed: 1.63s, reconstruction error: 16.91
# Epoch 10:	########################################	elapsed: 1.54s, reconstruction error: 15.69
# Epoch 11:	########################################	elapsed: 1.59s, reconstruction error: 14.69
# Epoch 12:	########################################	elapsed: 1.57s, reconstruction error: 13.88
# Epoch 13:	########################################	elapsed: 1.51s, reconstruction error: 13.11
# Epoch 14:	########################################	elapsed: 1.54s, reconstruction error: 12.58
# Epoch 15:	########################################	elapsed: 1.57s, reconstruction error: 12.11
# Epoch 16:	########################################	elapsed: 1.56s, reconstruction error: 11.53
# Epoch 17:	########################################	elapsed: 1.55s, reconstruction error: 11.19
# Epoch 18:	########################################	elapsed: 1.59s, reconstruction error: 10.89
# Epoch 19:	########################################	elapsed: 1.60s, reconstruction error: 10.58
# Epoch 20:	########################################	elapsed: 1.58s, reconstruction error: 10.25
# Epoch 21:	########################################	elapsed: 1.58s, reconstruction error: 10.10
# Epoch 22:	########################################	elapsed: 1.61s, reconstruction error: 9.83
# Epoch 23:	########################################	elapsed: 1.61s, reconstruction error: 9.60
# Epoch 24:	########################################	elapsed: 1.62s, reconstruction error: 9.46
# Epoch 25:	########################################	elapsed: 1.57s, reconstruction error: 9.37
# Epoch 26:	########################################	elapsed: 1.60s, reconstruction error: 9.31
# Epoch 27:	########################################	elapsed: 1.57s, reconstruction error: 9.11
# Epoch 28:	########################################	elapsed: 1.61s, reconstruction error: 8.98
# Epoch 29:	########################################	elapsed: 1.61s, reconstruction error: 8.98
# Epoch 30:	########################################	elapsed: 1.58s, reconstruction error: 8.87
# Epoch 31:	########################################	elapsed: 1.63s, reconstruction error: 8.81
# Epoch 32:	########################################	elapsed: 1.60s, reconstruction error: 8.81
# Epoch 33:	########################################	elapsed: 1.61s, reconstruction error: 8.69
# Epoch 34:	########################################	elapsed: 1.61s, reconstruction error: 8.63
# Epoch 35:	########################################	elapsed: 1.59s, reconstruction error: 8.57
# Epoch 36:	########################################	elapsed: 1.62s, reconstruction error: 8.51
# Epoch 37:	########################################	elapsed: 1.62s, reconstruction error: 8.44
# Epoch 38:	########################################	elapsed: 1.64s, reconstruction error: 8.32
# Epoch 39:	########################################	elapsed: 1.66s, reconstruction error: 8.38
# Epoch 40:	########################################	elapsed: 1.71s, reconstruction error: 8.29
# Epoch 41:	########################################	elapsed: 1.65s, reconstruction error: 8.38
# Epoch 42:	########################################	elapsed: 1.66s, reconstruction error: 8.21
# Epoch 43:	########################################	elapsed: 1.63s, reconstruction error: 8.22
# Epoch 44:	########################################	elapsed: 1.63s, reconstruction error: 8.19
# Epoch 45:	########################################	elapsed: 1.61s, reconstruction error: 8.20
# Epoch 46:	########################################	elapsed: 1.60s, reconstruction error: 8.14
# Epoch 47:	########################################	elapsed: 1.62s, reconstruction error: 8.08
# Epoch 48:	########################################	elapsed: 1.65s, reconstruction error: 8.18
# Epoch 49:	########################################	elapsed: 1.63s, reconstruction error: 8.09
# Epoch 50:	########################################	elapsed: 1.62s, reconstruction error: 8.13
#
# Learning layer 2
# Epoch 1:	########################################	elapsed: 0.90s, reconstruction error: 22.72
# Epoch 2:	########################################	elapsed: 0.88s, reconstruction error: 24.29
# Epoch 3:	########################################	elapsed: 0.87s, reconstruction error: 21.03
# Epoch 4:	########################################	elapsed: 0.87s, reconstruction error: 19.17
# Epoch 5:	########################################	elapsed: 0.85s, reconstruction error: 18.24
# Epoch 6:	########################################	elapsed: 0.87s, reconstruction error: 17.14
# Epoch 7:	########################################	elapsed: 0.89s, reconstruction error: 16.25
# Epoch 8:	########################################	elapsed: 0.87s, reconstruction error: 16.13
# Epoch 9:	########################################	elapsed: 0.89s, reconstruction error: 15.00
# Epoch 10:	########################################	elapsed: 0.89s, reconstruction error: 15.76
# Epoch 11:	########################################	elapsed: 0.87s, reconstruction error: 14.65
# Epoch 12:	########################################	elapsed: 0.91s, reconstruction error: 14.85
# Epoch 13:	########################################	elapsed: 0.91s, reconstruction error: 14.90
# Epoch 14:	########################################	elapsed: 0.89s, reconstruction error: 14.56
# Epoch 15:	########################################	elapsed: 0.89s, reconstruction error: 13.69
# Epoch 16:	########################################	elapsed: 0.90s, reconstruction error: 13.85
# Epoch 17:	########################################	elapsed: 0.90s, reconstruction error: 13.08
# Epoch 18:	########################################	elapsed: 0.88s, reconstruction error: 13.65
# Epoch 19:	########################################	elapsed: 0.90s, reconstruction error: 14.11
# Epoch 20:	########################################	elapsed: 0.89s, reconstruction error: 14.18
# Epoch 21:	########################################	elapsed: 0.90s, reconstruction error: 12.95
# Epoch 22:	########################################	elapsed: 0.90s, reconstruction error: 12.60
# Epoch 23:	########################################	elapsed: 0.93s, reconstruction error: 13.30
# Epoch 24:	########################################	elapsed: 0.90s, reconstruction error: 11.90
# Epoch 25:	########################################	elapsed: 0.88s, reconstruction error: 13.24
# Epoch 26:	########################################	elapsed: 0.89s, reconstruction error: 13.15
# Epoch 27:	########################################	elapsed: 0.88s, reconstruction error: 13.98
# Epoch 28:	########################################	elapsed: 0.88s, reconstruction error: 13.62
# Epoch 29:	########################################	elapsed: 0.88s, reconstruction error: 13.62
# Epoch 30:	########################################	elapsed: 0.88s, reconstruction error: 13.15
# Epoch 31:	########################################	elapsed: 0.87s, reconstruction error: 12.44
# Epoch 32:	########################################	elapsed: 0.88s, reconstruction error: 13.43
# Epoch 33:	########################################	elapsed: 0.91s, reconstruction error: 13.49
# Epoch 34:	########################################	elapsed: 0.89s, reconstruction error: 13.03
# Epoch 35:	########################################	elapsed: 0.91s, reconstruction error: 12.69
# Epoch 36:	########################################	elapsed: 0.88s, reconstruction error: 12.75
# Epoch 37:	########################################	elapsed: 0.89s, reconstruction error: 13.09
# Epoch 38:	########################################	elapsed: 0.88s, reconstruction error: 12.05
# Epoch 39:	########################################	elapsed: 0.89s, reconstruction error: 12.50
# Epoch 40:	########################################	elapsed: 0.88s, reconstruction error: 12.60
# Epoch 41:	########################################	elapsed: 0.89s, reconstruction error: 12.44
# Epoch 42:	########################################	elapsed: 0.87s, reconstruction error: 12.89
# Epoch 43:	########################################	elapsed: 0.87s, reconstruction error: 12.59
# Epoch 44:	########################################	elapsed: 0.88s, reconstruction error: 13.09
# Epoch 45:	########################################	elapsed: 0.89s, reconstruction error: 13.53
# Epoch 46:	########################################	elapsed: 0.93s, reconstruction error: 12.38
# Epoch 47:	########################################	elapsed: 0.91s, reconstruction error: 12.40
# Epoch 48:	########################################	elapsed: 0.88s, reconstruction error: 13.02
# Epoch 49:	########################################	elapsed: 0.87s, reconstruction error: 13.29
# Epoch 50:	########################################	elapsed: 0.86s, reconstruction error: 12.20
#
# Learning layer 3
# Epoch 1:	########################################	elapsed: 1.40s, reconstruction error: 13.63
# Epoch 2:	########################################	elapsed: 1.38s, reconstruction error: 14.06
# Epoch 3:	########################################	elapsed: 1.37s, reconstruction error: 15.11
# Epoch 4:	########################################	elapsed: 1.39s, reconstruction error: 14.29
# Epoch 5:	########################################	elapsed: 1.42s, reconstruction error: 13.38
# Epoch 6:	########################################	elapsed: 1.38s, reconstruction error: 13.74
# Epoch 7:	########################################	elapsed: 1.38s, reconstruction error: 13.80
# Epoch 8:	########################################	elapsed: 1.39s, reconstruction error: 14.24
# Epoch 9:	########################################	elapsed: 1.36s, reconstruction error: 13.96
# Epoch 10:	########################################	elapsed: 1.41s, reconstruction error: 12.83
# Epoch 11:	########################################	elapsed: 1.39s, reconstruction error: 13.34
# Epoch 12:	########################################	elapsed: 1.44s, reconstruction error: 13.31
# Epoch 13:	########################################	elapsed: 1.37s, reconstruction error: 13.95
# Epoch 14:	########################################	elapsed: 1.38s, reconstruction error: 14.13
# Epoch 15:	########################################	elapsed: 1.39s, reconstruction error: 12.91
# Epoch 16:	########################################	elapsed: 1.37s, reconstruction error: 14.74
# Epoch 17:	########################################	elapsed: 1.39s, reconstruction error: 13.47
# Epoch 18:	########################################	elapsed: 1.39s, reconstruction error: 14.36
# Epoch 19:	########################################	elapsed: 1.39s, reconstruction error: 13.33
# Epoch 20:	########################################	elapsed: 1.43s, reconstruction error: 12.67
# Epoch 21:	########################################	elapsed: 1.38s, reconstruction error: 13.96
# Epoch 22:	########################################	elapsed: 1.40s, reconstruction error: 13.41
# Epoch 23:	########################################	elapsed: 1.36s, reconstruction error: 12.77
# Epoch 24:	########################################	elapsed: 1.41s, reconstruction error: 13.34
# Epoch 25:	########################################	elapsed: 1.39s, reconstruction error: 13.76
# Epoch 26:	########################################	elapsed: 1.36s, reconstruction error: 13.20
# Epoch 27:	########################################	elapsed: 1.44s, reconstruction error: 13.23
# Epoch 28:	########################################	elapsed: 1.37s, reconstruction error: 13.10
# Epoch 29:	########################################	elapsed: 1.43s, reconstruction error: 13.00
# Epoch 30:	########################################	elapsed: 1.38s, reconstruction error: 12.83
# Epoch 31:	########################################	elapsed: 1.39s, reconstruction error: 12.29
# Epoch 32:	########################################	elapsed: 1.43s, reconstruction error: 12.46
# Epoch 33:	########################################	elapsed: 1.40s, reconstruction error: 12.97
# Epoch 34:	########################################	elapsed: 1.42s, reconstruction error: 13.22
# Epoch 35:	########################################	elapsed: 1.44s, reconstruction error: 13.13
# Epoch 36:	########################################	elapsed: 1.46s, reconstruction error: 12.67
# Epoch 37:	########################################	elapsed: 1.41s, reconstruction error: 12.34
# Epoch 38:	########################################	elapsed: 1.46s, reconstruction error: 12.87
# Epoch 39:	########################################	elapsed: 1.40s, reconstruction error: 12.49
# Epoch 40:	########################################	elapsed: 1.38s, reconstruction error: 12.60
# Epoch 41:	########################################	elapsed: 1.38s, reconstruction error: 12.47
# Epoch 42:	########################################	elapsed: 1.35s, reconstruction error: 12.33
# Epoch 43:	########################################	elapsed: 1.38s, reconstruction error: 12.24
# Epoch 44:	########################################	elapsed: 1.35s, reconstruction error: 12.31
# Epoch 45:	########################################	elapsed: 1.35s, reconstruction error: 12.62
# Epoch 46:	########################################	elapsed: 1.38s, reconstruction error: 12.61
# Epoch 47:	########################################	elapsed: 1.34s, reconstruction error: 12.21
# Epoch 48:	########################################	elapsed: 1.37s, reconstruction error: 12.45
# Epoch 49:	########################################	elapsed: 1.38s, reconstruction error: 12.21
# Epoch 50:	########################################	elapsed: 1.40s, reconstruction error: 12.13
# <h3>Finetuning pretrained MLP</h3>
# Epoch 1:	########################################	elapsed: 1.70s, accuracy: 93.01
# Epoch 2:	########################################	elapsed: 1.60s, accuracy: 94.57
# Epoch 3:	########################################	elapsed: 1.55s, accuracy: 95.03
# Epoch 4:	########################################	elapsed: 1.57s, accuracy: 93.99
# Epoch 5:	########################################	elapsed: 1.61s, accuracy: 94.76
# Epoch 6:	########################################	elapsed: 1.68s, accuracy: 95.46
# Epoch 7:	########################################	elapsed: 1.63s, accuracy: 95.69
# Epoch 8:	########################################	elapsed: 1.56s, accuracy: 96.01
# Epoch 9:	########################################	elapsed: 1.56s, accuracy: 95.23
# Epoch 10:	########################################	elapsed: 1.55s, accuracy: 95.51
# Epoch 11:	########################################	elapsed: 1.59s, accuracy: 96.00
# Epoch 12:	########################################	elapsed: 1.61s, accuracy: 96.38
# Epoch 13:	########################################	elapsed: 1.54s, accuracy: 96.36
# Epoch 14:	########################################	elapsed: 1.57s, accuracy: 96.70
# Epoch 15:	########################################	elapsed: 1.60s, accuracy: 96.74
# Epoch 16:	########################################	elapsed: 1.57s, accuracy: 96.87
# Epoch 17:	########################################	elapsed: 1.53s, accuracy: 97.04
# Epoch 18:	########################################	elapsed: 1.63s, accuracy: 97.17
# Epoch 19:	########################################	elapsed: 1.63s, accuracy: 97.13
# Epoch 20:	########################################	elapsed: 1.61s, accuracy: 97.15
# Epoch 21:	########################################	elapsed: 1.60s, accuracy: 97.16
# Epoch 22:	########################################	elapsed: 1.56s, accuracy: 97.14
# Epoch 23:	########################################	elapsed: 1.64s, accuracy: 97.14
# Epoch 24:	########################################	elapsed: 1.66s, accuracy: 97.12
# Epoch 25:	########################################	elapsed: 1.63s, accuracy: 97.12
# Epoch 26:	########################################	elapsed: 1.57s, accuracy: 97.15
# Epoch 27:	########################################	elapsed: 1.58s, accuracy: 97.14
# Epoch 28:	########################################	elapsed: 1.57s, accuracy: 97.14
# Epoch 29:	########################################	elapsed: 1.61s, accuracy: 97.13
# Epoch 30:	########################################	elapsed: 1.54s, accuracy: 97.13
# Epoch 31:	########################################	elapsed: 1.55s, accuracy: 97.12
# Epoch 32:	########################################	elapsed: 1.56s, accuracy: 97.14
# Epoch 33:	########################################	elapsed: 1.54s, accuracy: 97.14
# Epoch 34:	########################################	elapsed: 1.58s, accuracy: 97.14
# Epoch 35:	########################################	elapsed: 1.59s, accuracy: 97.12
# Epoch 36:	########################################	elapsed: 1.56s, accuracy: 97.13
# Epoch 37:	########################################	elapsed: 1.55s, accuracy: 97.13
# Epoch 38:	########################################	elapsed: 1.56s, accuracy: 97.13
# Epoch 39:	########################################	elapsed: 1.57s, accuracy: 97.12
# Epoch 40:	########################################	elapsed: 1.58s, accuracy: 97.12
# Epoch 41:	########################################	elapsed: 1.62s, accuracy: 97.12
# Epoch 42:	########################################	elapsed: 1.62s, accuracy: 97.12
# Epoch 43:	########################################	elapsed: 1.63s, accuracy: 97.12
# Epoch 44:	########################################	elapsed: 1.62s, accuracy: 97.13
# Epoch 45:	########################################	elapsed: 1.62s, accuracy: 97.13
# Epoch 46:	########################################	elapsed: 1.56s, accuracy: 97.13
# Epoch 47:	########################################	elapsed: 1.60s, accuracy: 97.14
# Epoch 48:	########################################	elapsed: 1.52s, accuracy: 97.14
# Epoch 49:	########################################	elapsed: 1.53s, accuracy: 97.14
# Epoch 50:	########################################	elapsed: 1.54s, accuracy: 97.15
# Training finished!
# <h3>First layer filters in the DBN</h3>
# <h3>Input layer filters in the pretrained & finetuned MLP</h3>
# <h3>Largest norms of weight-vectors in the finetuned MLP layers</h3>
# 	layer 1: 2.00
# 	layer 2: 1.00
# 	layer 3: 1.00
# 	layer 4: 4.00
